# %% [markdown]
# # IMPORTING THE LIBRARIES

# %%
import os
import pandas as pd
import pickle
import numpy as np
import seaborn as sns
from sklearn.datasets import load_files
from keras.utils import np_utils
import matplotlib.pyplot as plt
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
from keras.callbacks import ModelCheckpoint
from keras.utils import to_categorical
from sklearn.metrics import confusion_matrix
from keras.preprocessing import image                  
from tqdm import tqdm

import seaborn as sns
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

# %%
# Pretty display for notebooks
# %matplotlib inline

# %% [markdown]
# # Defining the train,test and model directories
#
# We will create the directories for train,test and model training paths if not present

# %%
TEST_DIR = os.path.join(os.getcwd(),"imgs","test")
TRAIN_DIR = os.path.join(os.getcwd(),"imgs","train")
MODEL_PATH = os.path.join(os.getcwd(),"model","self_trained")
PICKLE_DIR = os.path.join(os.getcwd(),"pickle_files")
CSV_DIR = os.path.join(os.getcwd(),"csv_files")

# %%
if not os.path.exists(TEST_DIR):
    print("Testing data does not exists")
if not os.path.exists(TRAIN_DIR):
    print("Training data does not exists")
if not os.path.exists(MODEL_PATH):
    print("Model path does not exists")
    os.makedirs(MODEL_PATH)
    print("Model path created")
if not os.path.exists(PICKLE_DIR):
    os.makedirs(PICKLE_DIR)
if not os.path.exists(CSV_DIR):
    os.makedirs(CSV_DIR)

# %% [markdown]
# # Data Preparation

# %% [markdown]
# We will create a csv file having the location of the files present for training and test images and their associated class if present so that it is easily traceable.

# %%
def create_csv(DATA_DIR,filename):
    class_names = os.listdir(DATA_DIR)
    data = list()
    if(os.path.isdir(os.path.join(DATA_DIR,class_names[0]))):
        for class_name in class_names:
            file_names = os.listdir(os.path.join(DATA_DIR,class_name))
            for file in file_names:
                data.append({
                    "Filename":os.path.join(DATA_DIR,class_name,file),
                    "ClassName":class_name
                })
    else:
        class_name = "test"
        file_names = os.listdir(DATA_DIR)
        for file in file_names:
            data.append(({
                "FileName":os.path.join(DATA_DIR,file),
                "ClassName":class_name
            }))
    data = pd.DataFrame(data)
    data.to_csv(os.path.join(os.getcwd(),"csv_files",filename),index=False)

create_csv(TRAIN_DIR,"train.csv")
create_csv(TEST_DIR,"test.csv")
data_train = pd.read_csv(os.path.join(os.getcwd(),"csv_files","train.csv"))
data_test = pd.read_csv(os.path.join(os.getcwd(),"csv_files","test.csv"))

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22424 entries, 0 to 22423
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Filename   22424 non-null  object
#  1   ClassName  22424 non-null  object
# dtypes: object(2)
# memory usage: 350.5+ KB

# %%
data_train['ClassName'].value_counts()
# Out:
# ClassName
# c0    2489
# c3    2346
# c4    2326
# c6    2325
# c2    2317
# c5    2312
# c1    2267
# c9    2129
# c7    2002
# c8    1911
# Name: count, dtype: int64

# %%
data_train.describe()
# Out:
#                                                  Filename ClassName
# count                                               22424     22424
# unique                                              22424        10
# top     C:\Users\Deepak L\Music\Distracted-Driver-Dete...        c0
# freq                                                    1      2489

# %%
nf = data_train['ClassName'].value_counts(sort=False)
labels = data_train['ClassName'].value_counts(sort=False).index.tolist()
y = np.array(nf)
width = 1/1.5
N = len(y)
x = range(N)

fig = plt.figure(figsize=(20,15))
ay = fig.add_subplot(211)

plt.xticks(x, labels, size=15)
plt.yticks(size=15)

ay.bar(x, y, width, color="blue")

plt.title('Bar Chart',size=25)
plt.xlabel('classname',size=15)
plt.ylabel('Count',size=15)

plt.show()

# %%
data_test.head()
# Out:
#                                             FileName ClassName
# 0  C:\Users\Deepak L\Music\Distracted-Driver-Dete...      test
# 1  C:\Users\Deepak L\Music\Distracted-Driver-Dete...      test
# 2  C:\Users\Deepak L\Music\Distracted-Driver-Dete...      test
# 3  C:\Users\Deepak L\Music\Distracted-Driver-Dete...      test
# 4  C:\Users\Deepak L\Music\Distracted-Driver-Dete...      test

# %%
data_test.shape
# Out:
# (79726, 2)

# %% [markdown]
# ## Observation:
# 1. There are total 22424 training samples
# 2. There are total 79726 training samples
# 3. The training dataset is equally balanced to a great extent and hence we need not do any downsampling of the data

# %% [markdown]
# ## Converting into numerical values

# %%
labels_list = list(set(data_train['ClassName'].values.tolist()))
labels_id = {label_name:id for id,label_name in enumerate(labels_list)}
print(labels_id)
data_train['ClassName'].replace(labels_id,inplace=True)
# Out:
# {'c8': 0, 'c5': 1, 'c6': 2, 'c4': 3, 'c0': 4, 'c2': 5, 'c1': 6, 'c7': 7, 'c3': 8, 'c9': 9}
# C:\Users\Deepak L\AppData\Local\Temp\ipykernel_15492\1324950157.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_train['ClassName'].replace(labels_id,inplace=True)
# C:\Users\Deepak L\AppData\Local\Temp\ipykernel_15492\1324950157.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_train['ClassName'].replace(labels_id,inplace=True)

# %%
with open(os.path.join(os.getcwd(),"pickle_files","labels_list.pkl"),"wb") as handle:
    pickle.dump(labels_id,handle)

# %%
labels = to_categorical(data_train['ClassName'])
print(labels.shape)
# Out:
# (22424, 10)

# %% [markdown]
# ## Splitting into Train and Test sets

# %%
from sklearn.model_selection import train_test_split

xtrain,xtest,ytrain,ytest = train_test_split(data_train.iloc[:,0],labels,test_size = 0.2,random_state=42)

# %% [markdown]
# ### Converting into 64*64 images
# You can substitute 64,64 to 224,224 for better results only if ram is >32gb

# %%
def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(64, 64))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %%
from PIL import ImageFile
from tensorflow.keras.preprocessing import image as tf_image


ImageFile.LOAD_TRUNCATED_IMAGES = True                 
def path_to_tensor(img_path):
    img = tf_image.load_img(img_path, target_size=(64, 64))
    x = tf_image.img_to_array(img)
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# pre-process the data for Keras
train_tensors = paths_to_tensor(xtrain).astype('float32')/255 - 0.5
# Out:
# 100%|██████████| 17939/17939 [04:49<00:00, 62.02it/s]

# %%
valid_tensors = paths_to_tensor(xtest).astype('float32')/255 - 0.5
# Out:
# 100%|██████████| 4485/4485 [00:53<00:00, 83.26it/s]

# %%
##takes too much ram 
## run this if your ram is greater than 16gb 
# test_tensors = paths_to_tensor(data_test.iloc[:,0]).astype('float32')/255 - 0.5

# %% [markdown]
# # Defining the Model

# %%
model = Sequential()

model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu', input_shape=(64,64,3), kernel_initializer='glorot_normal'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=128, kernel_size=2, padding='same', activation='relu', kernel_initializer='glorot_normal'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=256, kernel_size=2, padding='same', activation='relu', kernel_initializer='glorot_normal'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=512, kernel_size=2, padding='same', activation='relu', kernel_initializer='glorot_normal'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(500, activation='relu', kernel_initializer='glorot_normal'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax', kernel_initializer='glorot_normal'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 64)        832
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 128)       32896
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 256)       131328
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 512)         524800
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 512)        0
#  2D)
#
#  dropout (Dropout)           (None, 4, 4, 512)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 500)               4096500
#
#  dropout_1 (Dropout)         (None, 500)               0
#
#  dense_1 (Dense)             (None, 10)                5010
#
# =================================================================
# Total params: 4,791,366
# Trainable params: 4,791,366
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model,to_file=os.path.join(MODEL_PATH,"model_distracted_driver.png"),show_shapes=True,show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
filepath = os.path.join(MODEL_PATH,"distracted-{epoch:02d}-{val_accuracy:.2f}.hdf5")
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max',period=1)
callbacks_list = [checkpoint]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
model_history = model.fit(train_tensors,ytrain,validation_data = (valid_tensors, ytest),epochs=25, batch_size=40, shuffle=True,callbacks=callbacks_list)
# Out:
# Epoch 1/25
# 449/449 [==============================] - ETA: 0s - loss: 1.0625 - accuracy: 0.6246
# Epoch 1: val_accuracy improved from -inf to 0.89810, saving model to C:\Users\Deepak L\Music\Distracted-Driver-Detection-master\model\self_trained\distracted-01-0.90.hdf5
# 449/449 [==============================] - 208s 452ms/step - loss: 1.0625 - accuracy: 0.6246 - val_loss: 0.3243 - val_accuracy: 0.8981
# Epoch 2/25
# 449/449 [==============================] - ETA: 0s - loss: 0.2392 - accuracy: 0.9258
# Epoch 2: val_accuracy improved from 0.89810 to 0.94916, saving model to C:\Users\Deepak L\Music\Distracted-Driver-Detection-master\model\self_trained\distracted-02-0.95.hdf5
# 449/449 [==============================] - 212s 473ms/step - loss: 0.2392 - accuracy: 0.9258 - val_loss: 0.1805 - val_accuracy: 0.9492
# Epoch 3/25
# 449/449 [==============================] - ETA: 0s - loss: 0.1307 - accuracy: 0.9621
# Epoch 3: val_accuracy improved from 0.94916 to 0.97480, saving model to C:\Users\Deepak L\Music\Distracted-Driver-Detection-master\model\self_trained\distracted-03-0.97.hdf5
# 449/449 [==============================] - 210s 469ms/step - loss: 0.1307 - accuracy: 0.9621 - val_loss: 0.0807 - val_accuracy: 0.9748
# Epoch 4/25
# 449/449 [==============================] - ETA: 0s - loss: 0.0910 - accuracy: 0.9735
# Epoch 4: val_accuracy improved from 0.97480 to 0.98707, saving model to C:\Users\Deepak L\Music\Distracted-Driver-Detection-master\model\self_trained\distracted-04-0.99.hdf5
# 449/449 [==============================] - 212s 472ms/step - loss: 0.0910 - accuracy: 0.9735 - val_loss: 0.0510 - val_accuracy: 0.9871
# Epoch 5/25
# 449/449 [==============================] - ETA: 0s - loss: 0.0705 - accuracy: 0.9785
# Epoch 5: val_accuracy did not improve from 0.98707
# 449/449 [==============================] - 208s 463ms/step - loss: 0.0705 - accuracy: 0.9785 - val_loss: 0.0534 - val_accuracy: 0.9864
# Epoch 6/25
# 449/449 [==============================] - ETA: 0s - loss: 0.0637 - accuracy: 0.9820
# Epoch 6: val_accuracy improved from 0.98707 to 0.98863, saving model to C:\Users\Deepak L\Music\Distracted-Driver-Detection-master\model\self_trained\distracted-06-0.99.hdf5
# 449/449 [==============================] - 210s 467ms/step - loss: 0.0637 - accuracy: 0.9820 - val_loss: 0.0516 - val_accuracy: 0.9886
# Epoch 7/25
# 449/449 [==============================] - ETA: 0s - loss: 0.0578 - accuracy: 0.9827
# Epoch 7: val_accuracy improved from 0.98863 to 0.99130, saving model to C:\Users\Deepak L\Music\Distracted-Driver-Detection-master\model\self_trained\distracted-07-0.99.hdf5
# 449/449 [==============================] - 206s 460ms/step - loss: 0.0578 - accuracy: 0.9827 - val_loss: 0.0508 - val_accuracy: 0.9913
# Epoch 8/25
# 449/449 [==============================] - ETA: 0s - loss: 0.0547 - accuracy: 0.9844
# Epoch 8: val_accuracy did not improve from 0.99130
# 449/449 [==============================] - 205s 456ms/step - loss: 0.0547 - accuracy: 0.9844 - val_loss: 0.0741 - val_accuracy: 0.9851
# Epoch 9/25
# 449/449 [==============================] - ETA: 0s - loss: 0.0527 - accuracy: 0.9860
# Epoch 9: val_accuracy improved from 0.99130 to 0.99175, saving model to C:\Users\Deepak L\Music\Distracted-Driver-Detection-master\model\self_trained\distracted-09-0.99.hdf5
# 449/449 [==============================] - 205s 456ms/step - loss: 0.0527 - accuracy: 0.9860 - val_loss: 0.0446 - val_accuracy: 0.9918
# Epoch 10/25
# 449/449 [==============================] - ETA: 0s - loss: 0.0435 - accuracy: 0.9878
# Epoch 10: val_accuracy improved from 0.99175 to 0.99197, saving model to C:\Users\Deepak L\Music\Distracted-Driver-Detection-master\model\self_trained\distracted-10-0.99.hdf5
# 449/449 [==============================] - 205s 457ms/step - loss: 0.0435 - accuracy: 0.9878 - val_loss: 0.0388 - val_accuracy: 0.9920
# Epoch 11/25
# 449/449 [==============================] - ETA: 0s - loss: 0.0437 - accuracy: 0.9881
# Epoch 11: val_accuracy improved from 0.99197 to 0.99398, saving model to C:\Users\Deepak L\Music\Distracted-Driver-Detection-master\model\self_trained\distracted-11-0.99.hdf5
# 449/449 [==============================] - 203s 453ms/step - loss: 0.0437 - accuracy: 0.9881 - val_loss: 0.0412 - val_accuracy: 0.9940
# Epoch 12/25
# 449/449 [==============================] - ETA: 0s - loss: 0.0447 - accuracy: 0.9891
# Epoch 12: val_accuracy did not improve from 0.99398
# 449/449 [==============================] - 203s 452ms/step - loss: 0.0447 - accuracy: 0.9891 - val_loss: 0.0412 - val_accuracy: 0.9935
# Epoch 13/25
# 449/449 [==============================] - ETA: 0s - loss: 0.0401 - accuracy: 0.9895
# Epoch 13: val_accuracy did not improve from 0.99398
# 449/449 [==============================] - 204s 454ms/step - loss: 0.0401 - accuracy: 0.9895 - val_loss: 0.0450 - val_accuracy: 0.9918
# Epoch 14/25
# 449/449 [==============================] - ETA: 0s - loss: 0.0417 - accuracy: 0.9916
# Epoch 14: val_accuracy improved from 0.99398 to 0.99443, saving model to C:\Users\Deepak L\Music\Distracted-Driver-Detection-master\model\self_trained\distracted-14-0.99.hdf5
# 449/449 [==============================] - 202s 451ms/step - loss: 0.0417 - accuracy: 0.9916 - val_loss: 0.0367 - val_accuracy: 0.9944
# Epoch 15/25
# 449/449 [==============================] - ETA: 0s - loss: 0.0431 - accuracy: 0.9902
# Epoch 15: val_accuracy did not improve from 0.99443
# 449/449 [==============================] - 204s 454ms/step - loss: 0.0431 - accuracy: 0.9902 - val_loss: 0.0378 - val_accuracy: 0.9929
# Epoch 16/25
# 449/449 [==============================] - ETA: 0s - loss: 0.0379 - accuracy: 0.9905
# Epoch 16: val_accuracy improved from 0.99443 to 0.99554, saving model to C:\Users\Deepak L\Music\Distracted-Driver-Detection-master\model\self_trained\distracted-16-1.00.hdf5
# 449/449 [==============================] - 204s 454ms/step - loss: 0.0379 - accuracy: 0.9905 - val_loss: 0.0347 - val_accuracy: 0.9955
# Epoch 17/25
# 449/449 [==============================] - ETA: 0s - loss: 0.0466 - accuracy: 0.9900
# Epoch 17: val_accuracy did not improve from 0.99554
# 449/449 [==============================] - 205s 456ms/step - loss: 0.0466 - accuracy: 0.9900 - val_loss: 0.0361 - val_accuracy: 0.9955
# Epoch 18/25
# 449/449 [==============================] - ETA: 0s - loss: 0.0374 - accuracy: 0.9921
# Epoch 18: val_accuracy did not improve from 0.99554
# 449/449 [==============================] - 203s 452ms/step - loss: 0.0374 - accuracy: 0.9921 - val_loss: 0.1423 - val_accuracy: 0.9860
# Epoch 19/25
# 449/449 [==============================] - ETA: 0s - loss: 0.0476 - accuracy: 0.9911
# Epoch 19: val_accuracy did not improve from 0.99554
# 449/449 [==============================] - 203s 452ms/step - loss: 0.0476 - accuracy: 0.9911 - val_loss: 0.0772 - val_accuracy: 0.9895
# Epoch 20/25
# 449/449 [==============================] - ETA: 0s - loss: 0.0437 - accuracy: 0.9900
# Epoch 20: val_accuracy did not improve from 0.99554
# 449/449 [==============================] - 203s 453ms/step - loss: 0.0437 - accuracy: 0.9900 - val_loss: 0.0385 - val_accuracy: 0.9946
# Epoch 21/25
# 449/449 [==============================] - ETA: 0s - loss: 0.0342 - accuracy: 0.9921
# Epoch 21: val_accuracy improved from 0.99554 to 0.99576, saving model to C:\Users\Deepak L\Music\Distracted-Driver-Detection-master\model\self_trained\distracted-21-1.00.hdf5
# 449/449 [==============================] - 203s 451ms/step - loss: 0.0342 - accuracy: 0.9921 - val_loss: 0.0325 - val_accuracy: 0.9958
# Epoch 22/25
# 449/449 [==============================] - ETA: 0s - loss: 0.0389 - accuracy: 0.9920
# Epoch 22: val_accuracy did not improve from 0.99576
# 449/449 [==============================] - 203s 453ms/step - loss: 0.0389 - accuracy: 0.9920 - val_loss: 0.0557 - val_accuracy: 0.9946
# Epoch 23/25
# 449/449 [==============================] - ETA: 0s - loss: 0.0362 - accuracy: 0.9928
# Epoch 23: val_accuracy did not improve from 0.99576
# 449/449 [==============================] - 204s 455ms/step - loss: 0.0362 - accuracy: 0.9928 - val_loss: 0.0554 - val_accuracy: 0.9946
# Epoch 24/25
# 449/449 [==============================] - ETA: 0s - loss: 0.0320 - accuracy: 0.9938
# Epoch 24: val_accuracy did not improve from 0.99576
# 449/449 [==============================] - 204s 454ms/step - loss: 0.0320 - accuracy: 0.9938 - val_loss: 0.0909 - val_accuracy: 0.9933
# Epoch 25/25
# 449/449 [==============================] - ETA: 0s - loss: 0.0387 - accuracy: 0.9931
# Epoch 25: val_accuracy did not improve from 0.99576
# 449/449 [==============================] - 204s 454ms/step - loss: 0.0387 - accuracy: 0.9931 - val_loss: 0.0505 - val_accuracy: 0.9942

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12))
ax1.plot(model_history.history['loss'], color='b', label="Training loss")
ax1.plot(model_history.history['val_loss'], color='r', label="validation loss")
ax1.set_xticks(np.arange(1, 25, 1))
ax1.set_yticks(np.arange(0, 1, 0.1))

ax2.plot(model_history.history['accuracy'], color='b', label="Training accuracy")
ax2.plot(model_history.history['val_accuracy'], color='r',label="Validation accuracy")
ax2.set_xticks(np.arange(1, 25, 1))

legend = plt.legend(loc='best', shadow=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Model Analysis
#
# Finding the Confusion matrix,Precision,Recall and F1 score to analyse the model thus created

# %%
def print_confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    fig.savefig(os.path.join(MODEL_PATH,"confusion_matrix.png"))
    return fig

# %%
def print_heatmap(n_labels, n_predictions, class_names):
    labels = n_labels #sess.run(tf.argmax(n_labels, 1))
    predictions = n_predictions #sess.run(tf.argmax(n_predictions, 1))

#     confusion_matrix = sess.run(tf.contrib.metrics.confusion_matrix(labels, predictions))
    matrix = confusion_matrix(labels.argmax(axis=1),predictions.argmax(axis=1))
    row_sum = np.sum(matrix, axis = 1)
    w, h = matrix.shape

    c_m = np.zeros((w, h))

    for i in range(h):
        c_m[i] = matrix[i] * 100 / row_sum[i]

    c = c_m.astype(dtype = np.uint8)

    
    heatmap = print_confusion_matrix(c, class_names, figsize=(18,10), fontsize=20)

# %%
class_names = list()
for name,idx in labels_id.items():
    class_names.append(name)
# print(class_names)
ypred = model.predict(valid_tensors)
# Out:
# 141/141 [==============================] - 25s 80ms/step

# %%
print_heatmap(ytest,ypred,class_names)

# %% [markdown]
# ## Precision Recall F1 Score

# %%
ypred_class = np.argmax(ypred,axis=1)
# print(ypred_class[:10])
ytest = np.argmax(ytest,axis=1)

# %%
accuracy = accuracy_score(ytest,ypred_class)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(ytest, ypred_class,average='weighted')
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(ytest,ypred_class,average='weighted')
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(ytest,ypred_class,average='weighted')
print('F1 score: %f' % f1)
# Out:
# Accuracy: 0.994203
# Precision: 0.994227
# Recall: 0.994203
# F1 score: 0.994205
